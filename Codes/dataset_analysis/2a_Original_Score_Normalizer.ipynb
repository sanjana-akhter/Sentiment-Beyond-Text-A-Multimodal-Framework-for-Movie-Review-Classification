# %%
from google.colab import drive
import pandas as pd

# Mount Google Drive
drive.mount('/content/drive')


file_path = '/content/drive/MyDrive/THESIS 47/Saved Datasets/Dataset_A_200k_balanced_english_cap5.csv'

# Load dataset
df = pd.read_csv(file_path)

# Preview
df.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#                       id             title  \
# 0            nekrotronic       Nekrotronic
# 1   goodnight_mommy_2022   Goodnight Mommy
# 2       california_split  California Split
# 3              midsommar         Midsommar
# 4  the_leather_boys_1964  The Leather Boys
#
#                                           reviewText scoreSentiment  \
# 0  Ghostbusters meets The Matrix in this very ent...       NEGATIVE
# 1  Goodnight Mommy cannot avoid comparisons that ...       NEGATIVE
# 2  ...a distressingly erratic endeavor that never...       POSITIVE
# 3  High-art horror that won't suit all tastes, or...       POSITIVE
# 4  something rather different and much more inter...       POSITIVE
#
#   originalScore  audienceScore  tomatoMeter  runtimeMinutes  \
# 0           2/5           66.0         39.0            99.0
# 1          5/10           35.0         40.0            91.0
# 2           3/4           83.0         87.0           108.0
# 3           3/4           63.0         83.0           145.0
# 4         3.5/5           79.0         77.0           108.0
#
#                         genre     originalLanguage            director  \
# 0      Comedy, Horror, Sci-fi  English (Australia)  Kiah Roache-Turner
# 1          Mystery & thriller              English          Matt Sobel
# 2               Comedy, Drama              English       Robert Altman
# 3  Horror, Mystery & thriller              English           Ari Aster
# 4                       Drama              English     Sidney J. Furie
#
#     reviewId movieLangNorm
# 0    2508351       English
# 1  102732302       English
# 2    2810399       English
# 3    2601797       English
# 4    1383255       English

# %%
import re
import pandas as pd

# Classify each score into a type
def classify_score_type(score):
    if pd.isna(score):
        return 'missing'
    score = str(score).strip().upper()

    if '/' in score:
        return 'fraction'
    elif re.match(r'^[A-F][+-]?$', score):
        return 'grade'
    elif re.match(r'^\d+(\.\d+)?$', score):
        return 'numeric'
    else:
        return 'other'

# Apply classification
df['score_type'] = df['originalScore'].apply(classify_score_type)

# Show count of each type
type_counts = df['score_type'].value_counts()
print("🔍 Count of each score type:\n")
print(type_counts)

# Show all unique values for each type (not truncated)
pd.set_option('display.max_rows', None)  # ensures all values are printed

for score_type in type_counts.index:
    print(f"\n🔎 All values under type: {score_type}")
    values = df[df['score_type'] == score_type]['originalScore'].dropna().unique()
    print(sorted(values))  # sorted for easier reading
# Out:
# 🔍 Count of each score type:
#
# score_type
# fraction    167674
# grade        31176
# numeric        652
# other          498
# Name: count, dtype: int64
#
# 🔎 All values under type: fraction
# [' 3/5', "'1.5/4'", "'2.5/4'", "'2.5/5'", "'2.75/5'", "'2/4'", "'2/5'", "'3.25/5'", "'3.5/4", "'3.5/4'", "'3.75/5'", "'3/4'", "'3/5'", "'4/4'", '****1/2', '***1/2', '-1/10', '-1/4', '.01/5', '.25/4', '.5/ 5', '.5/10', '.5/4', '.5/4.0', '.5/5', '.66/10', '.7221/10', '.96/10', '0 / 5', '0.0/5', '0.0/5.0', '0.02/5', '0.23/5', '0.25/5', '0.3/5', '0.4/5', '0.5 / 5', '0.5/10', '0.5/4', '0.5/4.0', '0.5/5', '0.5/5.0', '0.52/1', '0.6/1', '0.7/5', '0.75/5', '0.8/5', '0.81/1', '0/10', '0/3', '0/4', '0/4.0', '0/5', '1 / 5', '1.0/4', '1.0/4.0', '1.0/5', '1.0/5.0', '1.1/2', '1.1/5', '1.2/10', '1.2/5', '1.24/5', '1.25/10', '1.25/5', '1.3/5', '1.4/4', '1.4/5', '1.5 / 5', '1.5/10', '1.5/2', '1.5/3', '1.5/4', '1.5/4.0', '1.5/5', '1.5/5.0', '1.6/5', '1.62/5', '1.7/5', '1.75/4', '1.75/5', '1.8/10', '1.8/4', '1.8/5', '1.9/5', '1/10', '1/3', '1/4', '1/4 stars', '1/5', '1/6', '10/10', '10/100', '10/20', '100/100', '11/20', '12.5/20', '12/100', '12/20', '13.5/20', '13/20', '14/20', '15.5/20', '15/100', '15/20', '16.5/20', '16/100', '16/20', '17.5/20', '17/100', '17/20', '18.5/20', '18/100', '18/20', '19/100', '19/20', '2 / 5', '2 1/2 stars', "2'/4", '2. 5 / 5', '2.0/10', '2.0/4', '2.0/4.0', '2.0/5', '2.0/5.0', '2.1/10', '2.1/2', '2.1/2`', '2.2/5', '2.25/4', '2.25/5', '2.282303/10', '2.3/10', '2.3/4', '2.3/5', '2.3/5.0', '2.4/10', '2.4/4', '2.4/5', '2.5 / 4', '2.5 / 5', '2.5/10', '2.5/20', '2.5/4', '2.5/4.0', '2.5/5', '2.5/5.0', '2.5/50', '2.5/6', '2.50/5', '2.55/4', '2.57/10', '2.6/10', '2.6/5', '2.65/10', '2.7/10', '2.7/5', '2.74/10', '2.75/10', '2.75/4', '2.75/5', '2.8/10', '2.8/4', '2.8/5', '2.83/5', '2.84/10', '2.85/5', '2.9/10', '2.9/5', '2/', '2/10', '2/100', '2/2', '2/3', '2/4', '2/4 ', '2/5', '2/5 ', '2/5/4', '2/6', '2/8', '2/9', '20/100', '22/100', '22/5', '23/100', '24/100', '25/100', '26/100', '27/100', '28/100', '29/100', '3 / 5', '3 1/2 stars', '3 1/2/4', '3.0/10', '3.0/4', '3.0/4.0', '3.0/5', '3.0/5.0', '3.1/10', '3.1/5', '3.1122428/10', '3.2/10', '3.2/5', '3.21/10', '3.2121/10', '3.222423/10', '3.25/10', '3.25/4', '3.25/5', '3.2592/10', '3.3/10', '3.3/5', '3.332/10', '3.35/5', '3.4/10', '3.4/4', '3.4/5', '3.45/10', '3.452433/10', '3.5 / 5', '3.5/ 5', '3.5/10', '3.5/18', '3.5/3', '3.5/4', '3.5/4.0', '3.5/5', '3.5/5.0', '3.5/5.5', '3.5/58', '3.55/10', '3.56339/10', '3.6/10', '3.6/5', '3.65/10', '3.7/10', '3.7/5', '3.724592250/10', '3.75/10', '3.75/4', '3.75/5', '3.75/5.0', '3.76/10', '3.8/10', '3.8/4', '3.8/5', '3.83412437/10', '3.9/10', '3.9/5', '3/10', '3
# ["'1'", "'1.5'", "'2'", "'2.5'", "'3'", "'4'", '*', '**', '***', '*****', '+1 out of -4..+4', '+2 out of -4..+4', '+3 out of -4..+4', '+4 out of -4..+4', '-1 out of -4..+4', '-2 out of -4..+4', '.5', '0 out of -4..+4', '0 out of 10', '0 stars', '1 star', '1-5 stars', '1.5 stars', '1.5.4', '10 out of 10', '2 Ripples', '2 of 5', '2 out of 10', '2 out of 5', '2 stars', '2.5 out of 10', '2.5 stars', '2.5.4', '2.5.5', '2\\5', '3 Ripples', '3 of 5', '3 out 5', '3 out of 5', '3 stars', "3'4", '3.5 of 5', '3.5 stars', '3.5.5', '3.5?4', '4 of 5', '4 out of 10', '4 out of 5 stars', '4 stars', '4.5 of 5', '4.5.5', '5 of 5', '6 out of 10', '6.5 out of 10', '6.8 out of 10', '60é100', '7 out of 10', '7 out of 10``', '7.0 out of 10', '7.5 out of 10', '7\\10', '8 out of 10', '8.5 out of 10', '9.5 out of 10', '???', 'A -', 'A minus', 'A-minus', 'A-plus', 'A=', 'A?', 'Aminus', 'B +', 'B -', 'B minus', 'B plus', 'B--', 'B-minus', 'B-plus', 'B_', 'Big Screen Watch', 'C +', 'C -', 'C minus', 'C plus', 'C-+', 'C-minus', 'C-plus', 'C=', 'C?', 'Catch It On Cable', 'FIVE STARS', 'FOUR STARS', 'Half Price', 'Highly Recommended', 'Not Recommended', 'ONE STAR', 'Olivia Wilde loses the makeup that made her the fa', 'Recommended', 'Strongly Not Recommended', 'THREE STARS', 'TWO STARS', 'Turkey!', 'ZERO STARS', '[mixed]', 'capsule', 'high +1 out of -4..+4', 'high +2 out of -4..+4', 'high -1 out of -4..+4', 'high 0 out of -4..+4', 'low +1 out of -4..+4', 'low +2 out of -4..+4', 'low +3 out of -4..+4', 'low 0 out of -4..+4', 'n', 'non-numerical', 'short']

# %%
import pandas as pd
import numpy as np
import re

# -------------------------------
# STEP 1: Filter out unwanted types
# -------------------------------
# Remove 'other' and 'numeric' score types
df = df[~df['score_type'].isin(['other', 'numeric'])].copy()

# -------------------------------
# STEP 2: Clean and Convert Fractions to 10
# -------------------------------
def clean_fraction(score):
    # Keep only valid fractions like 3/5 or 2.5/4 (no stars, letters, etc.)
    if isinstance(score, str) and re.match(r'^\d+(\.\d+)?/\d+(\.\d+)?$', score.strip()):
        try:
            num, denom = map(float, score.strip().split('/'))
            return round((num / denom) * 10, 2)
        except:
            return np.nan
    return np.nan

# Apply only to fraction type
df.loc[df['score_type'] == 'fraction', 'score_10'] = df.loc[df['score_type'] == 'fraction', 'originalScore'].apply(clean_fraction)

# -------------------------------
# STEP 3: Clean and Convert Grades to 10
# -------------------------------
grade_map = {
    'A+': 10, 'A': 9, 'A-': 8.5,
    'B+': 8, 'B': 7, 'B-': 6.5,
    'C+': 6, 'C': 5, 'C-': 4.5,
    'D+': 4, 'D': 3, 'D-': 2,
    'F': 1, 'F+': 1, 'F-': 1
}

def clean_grade(score):
    s = str(score).strip().upper()
    s = s.replace('PLUS', '+').replace('MINUS', '-').replace(' ', '')

    # Normalize aliases (like 'B PLUS', 'A- ', 'a', 'f+')
    return grade_map.get(s, np.nan)

# Apply only to grade type
df.loc[df['score_type'] == 'grade', 'score_10'] = df.loc[df['score_type'] == 'grade', 'originalScore'].apply(clean_grade)

# -------------------------------
# STEP 4: Final Cleaning
# -------------------------------
# Drop rows where score_10 is still NaN (invalid or unhandled cases)
df = df.dropna(subset=['score_10'])

# -------------------------------
# STEP 5: Summary Statistics
# -------------------------------
# Count unique scores and show
print("✅ Final Score Distribution (scale of 10):\n")
print(df['score_10'].value_counts().sort_index())

# Optional: show unique final scores
print("\n✅ Unique score_10 values used:")
print(sorted(df['score_10'].unique()))
# Out:
# ✅ Final Score Distribution (scale of 10):
#
# score_10
# 0.00      1842
# 0.04         1
# 0.20         1
# 0.40         1
# 0.46         1
# 0.50         7
# 0.60         2
# 0.75         1
# 0.80         2
# 0.83         1
# 0.90         2
# 1.00      1191
# 1.20         2
# 1.25       571
# 1.40         1
# 1.50        32
# 1.60         4
# 1.67        28
# 1.70         1
# 1.80         4
# 1.90         3
# 1.94         1
# 2.00      8164
# 2.10         2
# 2.20         4
# 2.22         1
# 2.28         1
# 2.30         2
# 2.40         7
# 2.48         1
# 2.50      5273
# 2.57         1
# 2.60        10
# 2.65         1
# 2.70         5
# 2.74         1
# 2.75         3
# 2.80        12
# 2.84         1
# 2.90         4
# 3.00      5798
# 3.10         9
# 3.11         1
# 3.20        10
# 3.21         2
# 3.22         1
# 3.24         1
# 3.25         1
# 3.26         1
# 3.30         9
# 3.33       124
# 3.40        19
# 3.45         2
# 3.50       118
# 3.55         1
# 3.56         1
# 3.60        17
# 3.65         1
# 3.70         9
# 3.72         1
# 3.75      6814
# 3.76         1
# 3.80        15
# 3.83         1
# 3.90        27
# 4.00     23152
# 4.02         1
# 4.03         1
# 4.10        22
# 4.15         1
# 4.17         1
# 4.18         1
# 4.20        24
# 4.21         3
# 4.24         1
# 4.25         7
# 4.27         1
# 4.29         1
# 4.30        14
# 4.35         1
# 4.38         1
# 4.40        25
# 4.41         1
# 4.42         2
# 4.45         2
# 4.48         1
# 4.50      3107
# 4.51         1
# 4.52         3
# 4.55         1
# 4.56         1
# 4.60        42
# 4.65         1
# 4.70        13
# 4.75         9
# 4.79         1
# 4.80        40
# 4.81         1
# 4.83         2
# 4.84         1
# 4.85         2
# 4.87         1
# 4.89         1
# 4.90        22
# 4.94         1
# 4.95         2
# 4.98         1
# 5.00     29353
# 5.01         1
# 5.02         1
# 5.05         1
# 5.10        25
# 5.16         1
# 5.19         1
# 5.20        32
# 5.21         1
# 5.22         2
# 5.23         2
# 5.25        12
# 5.28         1
# 5.29         2
# 5.30        21
# 5.35         1
# 5.40        34
# 5.44         1
# 5.45         5
# 5.50       299
# 5.51         1
# 5.53         1
# 5.55         1
# 5.57         1
# 5.60        28
# 5.61         1
# 5.62         1
# 5.65         2
# 5.66         1
# 5.70        31
# 5.72         1
# 5.75        25
.float64(7.02), np.float64(7.04), np.float64(7.05), np.float64(7.1), np.float64(7.11), np.float64(7.15), np.float64(7.18), np.float64(7.2), np.float64(7.21), np.float64(7.22), np.float64(7.25), np.float64(7.26), np.float64(7.27), np.float64(7.3), np.float64(7.4), np.float64(7.42), np.float64(7.5), np.float64(7.57), np.float64(7.6), np.float64(7.62), np.float64(7.65), np.float64(7.7), np.float64(7.75), np.float64(7.8), np.float64(7.85), np.float64(7.86), np.float64(7.87), np.float64(7.89), np.float64(7.9), np.float64(7.94), np.float64(7.95), np.float64(7.96), np.float64(8.0), np.float64(8.1), np.float64(8.12), np.float64(8.13), np.float64(8.15), np.float64(8.2), np.float64(8.21), np.float64(8.24), np.float64(8.25), np.float64(8.3), np.float64(8.32), np.float64(8.33), np.float64(8.35), np.float64(8.38), np.float64 ...

# %%
# Step 1: Remove scores greater than 10
before = df.shape[0]
df = df[df['score_10'] <= 10]
after = df.shape[0]

print(f"✅ Removed {before - after} rows where score_10 > 10.")

# Step 2: Check numeric range of score_10
min_score = df['score_10'].min()
max_score = df['score_10'].max()

print(f"\n✅ Remaining score_10 values are in the range: {min_score} to {max_score}")

# Step 3: Confirm only numeric values are present
is_numeric = pd.api.types.is_numeric_dtype(df['score_10'])
print(f"\n✅ Column `score_10` is numeric: {is_numeric}")

# Step 4 (optional): Final value counts
print("\n✅ Final cleaned score distribution:")
print(df['score_10'].value_counts().sort_index())
# Out:
# ✅ Removed 28 rows where score_10 > 10.
#
# ✅ Remaining score_10 values are in the range: 0.0 to 10.0
#
# ✅ Column `score_10` is numeric: True
#
# ✅ Final cleaned score distribution:
# score_10
# 0.00      1842
# 0.04         1
# 0.20         1
# 0.40         1
# 0.46         1
# 0.50         7
# 0.60         2
# 0.75         1
# 0.80         2
# 0.83         1
# 0.90         2
# 1.00      1191
# 1.20         2
# 1.25       571
# 1.40         1
# 1.50        32
# 1.60         4
# 1.67        28
# 1.70         1
# 1.80         4
# 1.90         3
# 1.94         1
# 2.00      8164
# 2.10         2
# 2.20         4
# 2.22         1
# 2.28         1
# 2.30         2
# 2.40         7
# 2.48         1
# 2.50      5273
# 2.57         1
# 2.60        10
# 2.65         1
# 2.70         5
# 2.74         1
# 2.75         3
# 2.80        12
# 2.84         1
# 2.90         4
# 3.00      5798
# 3.10         9
# 3.11         1
# 3.20        10
# 3.21         2
# 3.22         1
# 3.24         1
# 3.25         1
# 3.26         1
# 3.30         9
# 3.33       124
# 3.40        19
# 3.45         2
# 3.50       118
# 3.55         1
# 3.56         1
# 3.60        17
# 3.65         1
# 3.70         9
# 3.72         1
# 3.75      6814
# 3.76         1
# 3.80        15
# 3.83         1
# 3.90        27
# 4.00     23152
# 4.02         1
# 4.03         1
# 4.10        22
# 4.15         1
# 4.17         1
# 4.18         1
# 4.20        24
# 4.21         3
# 4.24         1
# 4.25         7
# 4.27         1
# 4.29         1
# 9.14         1
# 9.15         2
# 9.16         1
# 9.18         1
# 9.19         1
# 9.20        32
# 9.21         1
# 9.25         5
# 9.26         2
# 9.28         1
# 9.30        15
# 9.38         6
# 9.40        16
# 9.45         3
# 9.49         1
# 9.50       109
# 9.51         1
# 9.52         1
# 9.60         8
# 9.64         1
# 9.66         1
# 9.70         2
# 9.76         1
# 9.80         5
# 9.85         2
# 9.87         2
# 9.88         1
# 9.90         1
# 9.92         1
# 10.00     7430
# Name: count, dtype: int64

# %%
print(f"✅ Total number of rows in the cleaned dataset: {df.shape[0]}")
# Out:
# ✅ Total number of rows in the cleaned dataset: 198059

# %%
# Define path and save
output_path = '/content/drive/MyDrive/THESIS 47/Saved Datasets/All_languages_200k_data_save [Cleaned].csv'
df.to_csv(output_path, index=False)

print(f"✅ File saved successfully to: {output_path}")
# Out:
# ✅ File saved successfully to: /content/drive/MyDrive/THESIS 47/Saved Datasets/All_languages_200k_data_save [Cleaned].csv

# %%
# Load dataset
file_path = '/content/drive/MyDrive/THESIS 47/Saved Datasets/All_languages_200k_data_save [Cleaned].csv'
df = pd.read_csv(file_path)

# Show number of columns and their names
print(f"✅ Total number of columns: {df.shape[1]}")
print("📌 Column names:")
print(df.columns.tolist())
# Out:
# ✅ Total number of columns: 15
# 📌 Column names:
# ['id', 'title', 'reviewText', 'scoreSentiment', 'originalScore', 'audienceScore', 'tomatoMeter', 'runtimeMinutes', 'genre', 'originalLanguage', 'director', 'reviewId', 'movieLangNorm', 'score_type', 'score_10']

# %%
# Step 1: Drop unwanted columns
df.drop(columns=['score_type', 'originalScore'], inplace=True)

# Step 2: Rename 'score_10' to 'originalScore'
df.rename(columns={'score_10': 'originalScore'}, inplace=True)

# Step 3: Reorder columns: insert new 'originalScore' after 'scoreSentiment'
cols = df.columns.tolist()
# Remove 'originalScore' from end if exists
cols.remove('originalScore')
# Find index of 'scoreSentiment' and insert after it
insert_at = cols.index('scoreSentiment') + 1
cols.insert(insert_at, 'originalScore')

# Reorder DataFrame
df = df[cols]

# Confirm changes
print(f"✅ Final column count: {df.shape[1]}")
print("📌 Final column order:")
print(df.columns.tolist())
# Out:
# ✅ Final column count: 13
# 📌 Final column order:
# ['id', 'title', 'reviewText', 'scoreSentiment', 'originalScore', 'audienceScore', 'tomatoMeter', 'runtimeMinutes', 'genre', 'originalLanguage', 'director', 'reviewId', 'movieLangNorm']

# %%
# Define the path and save the file
output_path = '/content/drive/MyDrive/THESIS 47/Saved Datasets/[Original Score Normalized] All_languages_200k_data_save.csv'
df.to_csv(output_path, index=False)

print(f"✅ File saved successfully to: {output_path}")
# Out:
# ✅ File saved successfully to: /content/drive/MyDrive/THESIS 47/Saved Datasets/[Original Score Normalized] All_languages_200k_data_save.csv

# %%
print(f"✅ Total number of rows in the cleaned dataset: {df.shape[0]}")
# Out:
# ✅ Total number of rows in the cleaned dataset: 198059
